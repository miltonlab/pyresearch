# %%
# %matplotlib inline
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/backends/backend_gtk3.py:215: Warning: Source ID 7 was not found when attempting to remove it
#   GLib.source_remove(self._idle_event_id)

# %%
import matplotlib

# %%
import seaborn as sea
from numpy.random import randn
from numpy.random import rand
from numpy import cumsum

from matplotlib.pyplot import plot
from matplotlib.pyplot import autoscale
from matplotlib.pyplot import tight_layout
#import request
#import numpyp
#url = 'http://aima.cs.berkeley.edu/data/iris.csv'
#response = requests.get(url)

#data = numpy.fromstring(response.text)

# %%
from numpy import cumsum

# %%
sea.set_style("darkgrid")

# %%
seaborn.plt.plot(data[target=='setosa',0],data[target=='setosa',2],'bo')

# %%
#iris = seaborn.load_dataset('iris')
setosa = iris[iris['species'] == 'setosa'][[0, 2]]
versicolor = iris[iris['species'] == 'versicolor'][[0, 2]]
virginica = iris[iris['species'] == 'virginica'][[0, 2]]

# %%
tight_layout?

# %%
y = randn(100)
plot(y)

# %%
autoscale(tight='y')
tight_layout()
plot(y)

# %%
x=cumsum(rand(100))
plot(x, y, 'r-')

# %%
import numpy
import matplotlib.pyplot as plt

# %%
z = randn(100,2)
z[:,1] = 0.5*z[:,0] + numpy.sqrt(0.5)*z[:,1]
x = z[:,0]
y = z[:,1]
plt.subplot(1,2,1)
plt.scatter(x, y, label='Scatter 1')
plt.subplot(1,2,2)
plt.scatter(x, y, s=60, c='#FF7F00', marker='o', alpha=.5, label='Scatter 2')

# %%
plt.subplot?

# %%
# Out:
# array([-1.15094352, -0.46936075, -1.50525422,  1.60119087,  0.31751748,
#        -0.85443827,  0.59084259, -0.25340157, -1.90127167,  1.15358752])

# %%
z[:,0]+1
# Out:
# array([-0.15094352,  0.53063925, -0.50525422,  2.60119087,  1.31751748,
#         0.14556173,  1.59084259,  0.74659843, -0.90127167,  2.15358752])

# %%
-1.15094352+1
# Out:
# -0.15094352
